# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanthini03/DeepLearning/blob/branch1/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DataScience_SiyamalanSir
# %pwd
import os
os.listdir('.')
# Out:
# /content/drive/MyDrive/DataScience_SiyamalanSir
# ['Dataset',
#  '__pycache__',
#  'Net.py',
#  'main.py',
#  'DatasetLoader.py',
#  'MyResNet.py',
#  'CNNTrain.py',
#  'Untitled0.ipynb']

# %%
# %run CNNTrain.py

# %%
# %run main.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# lbl 	 Train 	 Test
# 0	   40	   10
# 1	   40	   10
# 2	   40	   10
# 	  120	   30
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 169MB/s]
# Epoch	TrLoss	TrAcc TeLoss
# 0 4.8196  37.500%   1.1255   33.333%
# 1 3.9399  50.833%   1.0657   43.333%
# 2 3.6189  64.167%   1.0953   46.667%
# 3 3.0995  65.833%   1.0819   50.000%
# 4 2.5902  76.667%   1.0566   46.667%
# 5 2.5595  75.000%   1.0148   60.000%
# ...

# %%
# %run main.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# lbl 	 Train 	 Test
# 0	   40	   10
# 1	   40	   10
# 2	   40	   10
# 	  120	   30
# Epoch	TrLoss	TrAcc TeLoss
# 0 5.1132  29.167%   1.1827   40.000%
# 1 4.4423  45.833%   1.1988   40.000%
# 2 3.9302  49.167%   1.1473   53.333%
# 3 3.1474  64.167%   1.2805   43.333%
# 4 2.6806  75.000%   1.1893   46.667%
# 5 2.5488  76.667%   1.2454   46.667%
# 6 2.2815  77.500%   1.0734   60.000%
# 7 2.1716  80.833%   1.1266   53.333%
# 8 1.9509  85.000%   1.0431   60.000%
# 9 1.5478  86.667%   1.0185   50.000%
# ...
